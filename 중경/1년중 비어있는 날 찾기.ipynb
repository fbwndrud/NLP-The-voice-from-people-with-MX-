# %%
import pandas as pd

# %%
dust = pd.read_csv('미세먼지.csv')

# %%
dust_cc = pd.read_csv(r'C:\Users\dty\Documents\github\fine dust2\data\미세먼지_daily.csv')

# %%
dust.date
# Out:
# 0      20180101
# 1      20180102
# 2      20180103
# 3      20180104
# 4      20180105
# 5      20180106
# 6      20180107
# 7      20180108
# 8      20180109
# 9      20180110
# 10     20180111
# 11     20180112
# 12     20180113
# 13     20180114
# 14     20180115
# 15     20180116
# 16     20180117
# 17     20180118
# 18     20180119
# 19     20180120
# 20     20180121
# 21     20180122
# 22     20180123
# 23     20180124
# 24     20180125
# 25     20180126
# 26     20180127
# 27     20180128
# 28     20180129
# 29     20180130
#          ...
# 279    20181202
# 280    20181203
# 281    20181204
# 282    20181205
# 283    20181206
# 284    20181207
# 285    20181208
# 286    20181209
# 287    20181210
# 288    20181211
# 289    20181212
# 290    20181213
# 291    20181214
# 292    20181215
# 293    20181216
# 294    20181217
# 295    20181218
# 296    20181219
# 297    20181220
# 298    20181221
# 299    20181222
# 300    20181223
# 301    20181224
# 302    20181225
# ...

# %%
dust_cc = dust_cc.loc[dust_cc.pm25 != 'pm25',:]

# %%
dust_cc.pm25 = pd.to_numeric(dust_cc.pm25)
# Out:
# C:\Users\dty\.conda\envs\June\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
dust_cc.pm25
# Out:
#       date_daily                pm10               noise                temp  \
# 0       20180401   74.55902777777777   34.77986111111111    16.6592361111111
# 1       20180401   64.62239221140473   49.46453407510431   16.70312934631431
# 2       20180401   51.21323011963406   35.88881069669247  17.022871217452426
# 3       20180401   52.72708333333333  54.077083333333334  17.280972222222236
# 4       20180401   63.60380014074595   53.43631245601689  17.675580577058437
# 5       20180401   53.55486111111111  49.230555555555554   17.39965277777778
# 6       20180401   55.55416666666667  48.890277777777776   16.19868055555553
# 7       20180401   66.68619246861925   52.31938633193863   16.59790794979076
# 8       20180401   45.38423988842399   52.50348675034868  17.708228730822835
# 9       20180401   66.04097222222222  49.981944444444444  16.913819444444478
# 10      20180401  59.375174337517436  44.316596931659696  17.294839609483958
# ...

# %%
import pandas

dt_index = pandas.date_range(start='20180101', end='20181231')
# pandas.date_range(start='20160901', end='20161031',freq='W-MON')
# 을 하면 해당 기간 매주 월요일들만 추출합니다.

# type(dt_index) => DatetimeIndex
# DatetimeIndex => list(str)
dt_list = dt_index.strftime("%Y%m%d").tolist()

# for i in dt_list:
#     print(i)

# %%
date_list = dust.date.tolist()

# %%
for idx in date_list:
    dt_list.remove(str(idx))

# %%
dt_list
# Out:
# ['20180217',
#  '20180321',
#  '20180322',
#  '20180323',
#  '20180324',
#  '20180325',
#  '20180326',
#  '20180327',
#  '20180328',
#  '20180329',
#  '20180330',
#  '20180331',
#  '20180401',
#  '20180402',
#  '20180403',
#  '20180404',
#  '20180405',
#  '20180406',
#  '20180407',
#  '20180408',
#  '20180420',
#  '20180518',
#  '20180519',
#  '20180522',
#  '20180523',
#  '20180524',
#  '20180525',
#  '20180526',
#  '20180529',
#  '20180530',
#  '20180531',
#  '20180603',
#  '20180606',
#  '20180607',
#  '20180608',
#  '20180609',
#  '20180610',
#  '20180611',
#  '20180612',
#  '20180613',
#  '20180614',
#  '20180615',
#  '20180616',
#  '20180617',
#  '20180618',
#  '20180619',
#  '20180620',
#  '20180621',
#  '20180623',
#  '20180624',
#  '20180625',
#  '20180627',
#  '20180628',
#  '20180629',
#  '20180704',
#  '20180705']
